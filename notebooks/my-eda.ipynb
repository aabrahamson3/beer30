# %% [markdown]
# If we list all the natural numbers below 10 that are multiples of 3 or 5, we get 3, 5, 6 and 9. The sum of these multiples is 23. Find the sum of all the multiples of 3 or 5 below 2340.

# %%
test = []
for i in range(1,2682):
    if (i % 3 == 0) or (i % 5 == 0):
        test.append(i)
print (sum(test))
# Out:
# 1678128

# %%
import math
print(math.factorial(52)/math.factorial(42))
# Out:
# 5.7407703889536e+16

# %%
import math
math.factorial(52) - math.factorial(52-34)
# Out:
# 80658175170943878571660636856403766975289505440883271421626294272000

# %%
import pandas as pd
beer = pd.read_csv('beers.csv')

# %%
beer.head()
# Out:
#    id  brewery_id                    name  cat_id  style_id  abv  ibu  srm  \
# 0   1         812             Hocus Pocus      11       116  4.5  0.0  0.0
# 1   2         264       Grimbergen Blonde      -1        -1  6.7  0.0  0.0
# 2   3         779  Widdershins Barleywine      -1        -1  9.1  0.0  0.0
# 3   4         287                 Lucifer      -1        -1  8.5  0.0  0.0
# 4   5        1056                  Bitter      -1        -1  4.0  0.0  0.0
#
#    upc filepath                                           descript  add_user  \
# 0    0      NaN  Our take on a classic summer ale.  A toast to ...         0
# 1    0      NaN                                                NaN         0
# 2    0      NaN                                                NaN         0
# 3    0      NaN                                                NaN         0
# 4    0      NaN                                                NaN         0
#
#                   last_mod
# ...

# %%
breweries = pd.read_csv('breweries.csv')

# %%
breweries.loc[breweries['name']=='Magic Hat']
# Out:
#       id       name             address1 address2              city    state  \
# 803  812  Magic Hat  5 Bartlett Bay Road      NaN  South Burlington  Vermont
#
#      code        country           phone                   website filepath  \
# 803  5403  United States  1-802-658-2739  http://www.magichat.net/      NaN
#
#                                               descript  add_user  \
# 803  Burlington microbrewers of Humble Patience, Fa...         0
#
#                     last_mod
# 803  2010-07-22 20:00:20 UTC

# %%
beer.merge(breweries,left_on='brewery_id',right_on='id')
# Out:
#       id_x  brewery_id                   name_x  cat_id  style_id  abv  ibu  \
# 0        1         812              Hocus Pocus      11       116  4.5  0.0
# 1     3776         812                       #9       3        26  4.6  0.0
# 2     3810         812                Lucky Kat       3        31  5.8  0.0
# 3     3949         812                     HIPA       3        31  6.8  0.0
# 4     4154         812               Circus Boy       4        50  5.2  0.0
# ...    ...         ...                      ...     ...       ...  ...  ...
# 5896  5900        1419  Koshihikari Echigo Beer      11       132  5.0  0.0
# 5897  5901        1420                Full Boar      11       132  0.0  0.0
# 5898  5902        1421               The Public       3        26  6.0  0.0
# 5899  5913        1422                Abhi beer       7        89  0.0  0.0
# 5900  5914        1423                     Ambr      11       132  0.0  0.0
#
# ...
