# %% [markdown]
# ## This notebook comprises my initial EDA and cleaning of my dataset (obtained here: https://www.kaggle.com/ehallmar/beers-breweries-and-beer-reviews)

# %%
# Import EDA packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
beers = pd.read_csv('beers-breweries-and-beer-reviews/beers.csv')
breweries = pd.read_csv('beers-breweries-and-beer-reviews/breweries.csv')
reviews = pd.read_csv('beers-breweries-and-beer-reviews/reviews.csv')

# %% [markdown]
# ### Exploring the reviews

# %%
reviews.shape
# Out:
# (9073128, 10)

# %%
reviews.columns
# Out:
# Index(['beer_id', 'username', 'date', 'text', 'look', 'smell', 'taste', 'feel',
#        'overall', 'score'],
#       dtype='object')

# %%
reviews.username.value_counts()
# Out:
# Sammy            13798
# kylehay2004      12221
# acurtis          12016
# StonedTrippin    11859
# jaydoc           11800
#                  ...
# ezerhoden14          1
# hubbitron            1
# Kec                  1
# Bozorgmehr           1
# pekenne              1
# Name: username, Length: 164934, dtype: int64

# %%
# visualize the number of reviews per use for all users
sns.distplot(reviews.username.value_counts(),hist=False)

# %% [markdown]
# The above plot is expected, most users have made a smaller number of reviews. The number of users with a lot of reviews is very small. Out of 165k reviewers, there are ~1820 that have more than 1000 reviews.

# %%
reviews.username.value_counts()[1820:]
# Out:
# jwinship83         1000
# jooler             1000
# falloutsnow        1000
# Stum-pub           1000
# Aaron_Kerkvliet     998
#                    ...
# pprotz00              1
# Aharts                1
# Mark_Erden            1
# Erich_Langner         1
# stixfix               1
# Name: username, Length: 163114, dtype: int64

# %%
reviews.head()
# Out:
#    beer_id         username        date  \
# 0   271781     bluejacket74  2017-03-17
# 1   125646          _dirty_  2017-12-21
# 2   125646          CJDUBYA  2017-12-21
# 3   125646  GratefulBeerGuy  2017-12-20
# 4   125646         LukeGude  2017-12-20
#
#                                                 text  look  smell  taste  \
# 0     750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00   4.00
# 1                                                     4.50   4.50   4.50
# 2                                                     4.75   4.75   4.75
# 3     0% 16 oz can. Funny story: As I finally wal...  4.75   4.75   4.50
# 4     Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50   4.25
#
#    feel  overall  score
# 0  4.25     4.00   4.03
# 1  4.50     4.50   4.50
# 2  4.75     4.75   4.75
# 3  4.50     4.50   4.58
# 4  4.25     4.25   4.31

# %%
reviews.beer_id.value_counts()
# Out:
# 11757     17160
# 2093      15947
# 7971      14927
# 1093      14915
# 29619     14292
#           ...
# 203777        1
# 126326        1
# 109950        1
# 282050        1
# 8188          1
# Name: beer_id, Length: 309542, dtype: int64

# %%
sns.distplot(reviews.beer_id)

# %% [markdown]
# The above shows a not so typical long tail associated with recommender systems. That is there is a small number of items that are very popular or are reviewed by many, and then this trails off and most items are not seen by most users. The above graph shows this general trend.

# %%
# looking at the text reviews series
reviews['text']
# Out:
# 0             750 ml bottle, 2016 vintage, bottle #304 of...
# 1
# 2
# 3             0% 16 oz can. Funny story: As I finally wal...
# 4             Classic TH NEIPA. Overflowing head and bouq...
#                                  ...
# 9073123
# 9073124
# 9073125
# 9073126
# 9073127
# Name: text, Length: 9073128, dtype: object

# %%
# The blank spaces actually have a unicode character, let's get rid of it
reviews.iloc[2].text
# Out:
# '\xa0\xa0'

# %%
# Replace it with a blank string
reviews['text'] = reviews['text'].replace(u'\xa0\xa0', '')
# Confirming this is successful
reviews.iloc[2].text
# Out:
# ''

# %%
# Loks like there are 6 million reviews with no text, that's too bad.
reviews.loc[reviews['text'] == '']
# Out:
#          beer_id          username        date text  look  smell  taste  feel  \
# 1         125646           _dirty_  2017-12-21       4.50   4.50   4.50  4.50
# 2         125646           CJDUBYA  2017-12-21       4.75   4.75   4.75  4.75
# 5         125646           jneff33  2017-12-20       4.50   4.75   5.00  5.00
# 6         125646         yummybeer  2017-12-19       4.75   4.50   4.75  4.75
# 8         125646              wwoj  2017-12-16       5.00   4.75   4.50  4.50
# ...          ...               ...         ...  ...   ...    ...    ...   ...
# 9073123   104824            CTJman  2014-06-08        NaN    NaN    NaN   NaN
# 9073124   104824  IMSPEAKNOENGLISH  2014-06-06        NaN    NaN    NaN   NaN
# 9073125   104824          twizzard  2014-06-05        NaN    NaN    NaN   NaN
# 9073126   104824        bootdown21  2014-06-04        NaN    NaN    NaN   NaN
# 9073127   104824           Brensol  2014-06-01        NaN    NaN    NaN   NaN
#
#          overall  score
# 1           4.50   4.50
# 2           4.75   4.75
# 5           5.00   4.91
# 6           4.75   4.69
# 8           4.50   4.59
# ...          ...    ...
# 9073123      NaN   4.00
# 9073124      NaN   5.00
# 9073125      NaN   5.00
# 9073126      NaN   4.50
# 9073127      NaN   4.75
#
# [6085135 rows x 10 columns]

# %% [markdown]
# ## Will most likely use the below subset only reviews that have text

# %%
reviews.loc[reviews['text'] != '']
# Out:
#          beer_id         username        date  \
# 0         271781     bluejacket74  2017-03-17
# 3         125646  GratefulBeerGuy  2017-12-20
# 4         125646         LukeGude  2017-12-20
# 7         125646             MFMB  2017-12-16
# 13        125646      jngrizzaffi  2017-12-10
# ...          ...              ...         ...
# 9073095    58482           smcolw  2009-08-22
# 9073096    58482    firkinhophead  2009-08-21
# 9073097    58482          CHADMC3  2009-08-21
# 9073110   104824     zookerman182  2014-06-24
# 9073114   104824        Hesscabob  2014-06-18
#
#                                                       text  look  smell  \
# 0           750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00
# 3           0% 16 oz can. Funny story: As I finally wal...  4.75   4.75
# 4           Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50
# 7           Pours a creamy opaque light straw yellow wi...  4.75   4.50
# 13          Pours a cloudy yellow color with a thin foa...  4.50   4.50
# ...                                                    ...   ...    ...
# 9073095     Large chalky white head. Leaves lots of spo...  4.00   3.50
# 9073096     pours a hazy, almost cloudy, autumn gold. A...  3.50   4.00
# 9073097     Pours a hazy golden/orange to copper with a...  4.00   4.00
# 9073110     Appearance is dark dark brown with a half f...  4.25   4.75
# 9073114     Shared botte. A - Murky, brown, hardly any ...  4.00   5.00
#
#          taste  feel  overall  score
# 0         4.00  4.25     4.00   4.03
# 3         4.50  4.50     4.50   4.58
# 4         4.25  4.25     4.25   4.31
# 7         4.50  4.50     4.50   4.52
# 13        4.50  4.75     4.50   4.53
# ...        ...   ...      ...    ...
# 9073095   3.50  4.00     3.50   3.58
# 9073096   4.00  3.50     4.00   3.92
# 9073097   3.50  4.00     4.00   3.80
# 9073110   4.25  4.00     4.25   4.35
# 9073114   4.75  4.25     4.50   4.67
#
# [2987993 rows x 10 columns]

# %%
# Subsetting the reviews df to entries that only have text reviews
text_reviews = reviews.loc[reviews['text'] != '']

# %%
text_reviews.text.value_counts()
# Out:
#    0%                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         78177
#    You had this beer. Write a review.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          2616
#    On tap at the brewery                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         95
#    Sampled from bottle                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           92
#    C / AVERAGE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   92
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
#    On tap at the Falling Rock Tap House in Denver, CO, on my 30th Wedding Anniversary. I LOVE cloudy beers, and this one was very cloudy, light yellow, under a small, tight white head that lasted very well. (BTW, they now how to pour a beer at Falling Rock!!). Smell is orange, clove, slight maltiness, citrus hops, slight apple fruitiness. Crisp and nice. Taste is clove, orange, coriander, wheat-malt: WOWOWOWOWOW! Dry peppery finish. I mean WOWOWOWOW! Mouthfeel was surprisingly full from the soft carbonation. Very, very drinkable. If you can get this on tap, give it a try and enjoy! EDIT, AUGUST 3, 2006 Bottled version is just a notch down in smell and taste, which drops the drinkability a bit as well. Otherwise much the same. Hence . . . A 4.0 S 3.5 T 4.0 M 3.5 D 4.0 yielding an average of 3.85. By the way, this goes great with spicey food.                                                                                                                                                                                                              1
#    Double Bock Fans, wanna try a new spin on the style? Here's a slightly Hoppy double Bock that's worth a try. A: Amber, Chestnut, opaque S: Some smoke and Malt, but more spicey T: Slightly sweet Malt battles with Hops for your attention. This is a relatively high alcohol brew but the alcohol does not completely dominate. The hops is faintly reminiscent of the hoppy CAB IPA (which I like a lot), and works well. Aftertaste is a bit bitter and the alcohol lingers just a little on the palate. M: Mouthfeel is thin to medium, a little more carbonated than I prefer but fairly smooth. D: These are good for one or two, very drinkable for a 7.5% brew. I look forward to more offerings from this fine brewery.                                                                                                                                                                                                                                                                                                                                                              1
#    Lime sour weisse. Could be the best beer i've ever had. the crowler they filled for me at the brewery stayed fresh for 2 weeks. amazing key lime pie in a glass. make more!!!!                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
#    750ml served in a St Bernardus goblet A - Pours a murky brown color with mahogany hues. Thin head of beige bubbles separate to form a solid collar. S - Lots going on here, lots of spice and fruit esters, bananas, cherries, figs, raisins, vinous grapes, sugary dates are the most prominent. Smells like a moist fruit cake. Deep and rich toffee/caramel malts. T - Fruit galore, figs, dates, apples, bananas, cherries, the orange peel really comes out in the flavor. A malty burnt toffee backbone creates a solid base and is infused with lots of spices, cinnamon nutmeg, cardamon, anise, pepper, coriander, and the weird one that I have no idea what it tastes like is mace. There's so many that I wouldn't have been able to pick all of them out if it wasn't on the bottle. The finish is yeasty and spicy. M - Moderate carbonation, medium body with a bulky feel. They did not mess around when it comes to the amount of spices in this beer. Loads of fruit as well as a dense maltyness. Almost too much going on at once. This is to be sipped for sure.          1
#    Poured from a 12 oz bottle into nonic pint glass. A - Slightly hazy, orange-ish copper with a finger of white head that dissipated quickly into nothing, leaving no lace. S - A nice bit of cinnamon and vanilla with a touch of citrus in the background. Not very complex but pleasing. T - This brew is borderline tasteless. A very thin graininess heads things up, with a strange sourish component that tastes vaguely of pumpkin. A bitter and slightly roasted character appears as well. Near the end there is a wash of fruity, almost citric vanilla flavor. Faint overall. M - Highly carbonated and very light bodied. I don't understand why breweries bother making pumpkin ales so light and spritzy; it does nothing to enhance flavor. D - With all it's flaws, it's not a difficult beer to drink and the spice profile is slightly interesting. A poor example of the style, but thankfully not all that offensive.                                                                                                                                                       1
# Name: text, Length: 2897962, dtype: int64

# %%
text_reviews.loc[text_reviews['text'] == '0%']
# Out:
# Empty DataFrame
# Columns: [beer_id, username, date, text, look, smell, taste, feel, overall, score]
# Index: []

# %%
text_reviews.smell.isna().sum()
# Out:
# 164241

# %%
# Confirming that the entries with NaN smell/taste/feel/overall score are the same reviews
(text_reviews[text_reviews.smell.isna() == True].index == text_reviews[text_reviews.overall.isna() == True].index).sum()
# Out:
# 164241

# %% [markdown]
# ### 164k of the text_reviews subset has NaN attribute ratings, whole dataset has 3.8 million. Makes sense as those that fill out a text review are likely to fill out the numerical ratings

# %%
# subset data to exclude NaN's as well
text_no_nan = text_reviews.loc[text_reviews.smell.isna() == False]

# %%
# reconfirming distrubtion of # of reviews per beer, still looks to be as expected
sns.distplot(text_no_nan.beer_id)

# %%
# Distribution of the mean score for each beer is mostly normal with a negative skewness
sns.distplot(text_no_nan.groupby(['beer_id']).score.mean())

# %% [markdown]
# ## 210k beers have been reviewed in the subset of 'text_reviews': no empty text, but NaN attributes (2.99 million reviews)
#
# ## 137k beers have been reviewed in the subset 'text_no_nan': no empty text, no NaN attribute (2.8 million reviews)

# %%
(text_no_nan.beer_id.value_counts() > 49).sum()
# Out:
# 8928

# %%
(text_no_nan.beer_id.value_counts() > 9).sum()
# Out:
# 31310

# %% [markdown]
#  Only ~9k beers have 50+ reviews, 31k with 10+.
#
# ### BeerAdvocate users 10+ as a metric before assigning a beer scores based on their own algorithm, so this is the cutoff I will use as well

# %%
len(text_no_nan.username.unique())
# Out:
# 81629

# %%
len(text_no_nan.beer_id.unique())
# Out:
# 136535

# %%
text_no_nan['text'].sample()
# Out:
# 1606246       Served in a traditional Paulaner Weizen Glass, this beer was a cloudy lemon yellow, and topped by a rather modest (for a weizen) slightly off-white head. However, it displayed good retention and a decent lacing. Aroma was more banana than clove, and was very fresh. The flavor has a nice crispness to it, with more banana flavors. Mouthfeel was rather smooth, yet fully carbonated. Drinkability was very good, as I had 60 ounces in a short period of time. I actually expected this to be the pils, since there was absolutely nothing else worthwhile on tap. Nice surprise when a hefe showed up, and a good one at that.
# Name: text, dtype: object

# %%
text_no_nan.iloc[1606247,:]
# Out:
# beer_id     34069
# username    avalon07
# date        2008-12-16
# text           A: Poured from a bottle to a pint glass. Had an amber color and a mainly clear consistency. There was a quarter inch of head and some good lacing. S: Smell was dominated by the malt, though some hops emerged. T: Tasted more of malt than anything, with mild hops. Not the most complex piece of brewing I've ever had. M: A fair amount of carbonation and a dry finish. Medium-bodied. D: Overall, this is an OK beer, but it didn't do that much for me.
# look        3.5
# smell       3.5
# taste       3.5
# feel        3.5
# overall     3.5
# score       3.5
# Name: 4959228, dtype: object

# %%
text_no_nan
# Out:
#          beer_id         username        date  \
# 0        271781   bluejacket74     2017-03-17
# 3        125646   GratefulBeerGuy  2017-12-20
# 4        125646   LukeGude         2017-12-20
# 7        125646   MFMB             2017-12-16
# 13       125646   jngrizzaffi      2017-12-10
# ...         ...           ...             ...
# 9073095  58482    smcolw           2009-08-22
# 9073096  58482    firkinhophead    2009-08-21
# 9073097  58482    CHADMC3          2009-08-21
# 9073110  104824   zookerman182     2014-06-24
# 9073114  104824   Hesscabob        2014-06-18
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text  \
# 0           750 ml bottle, 2016 vintage, bottle #304 of 360. Served in a DFH snifter, the beer pours dark brown/black with about an inch tan head that stuck around a little while. There's also a good amount of lacing. I like the aroma, the brew smells like dark fruit (raisin, plum), chocolate, roasted malt, and a bit of licorice. For the most part I think the taste is just like the aroma, but with some coffee flavor noticeable too. Mouthfeel/body is medium/full, it's creamy and coating with a moderate amount of carbonation. I think it's a good overall brew, worth picking up if you want a nice straight forward imperial stout. Here's hoping Four String brings this back in the future! $9.99 a bottle.
# 3           0% 16 oz can. Funny story: As I finally walked in the doors after a 45 min wait in line and freezing temps the sweet sound of the Grateful Dead's Sugar Magnolia greeted me from the TreeHouse sound system. The bottom of the can reads: "Going where the wind goes, bloomin' like a red rose" A white haze to the yellow and golden liquid. Thick and healthy, totally unfiltered. Brawny white foam cap, thick, all-white clumps. Huge lacing left over. The aroma has a very zesty citrus hop effect, mellon and mango, grainy earthiness, tropical fruit blend with a bitter to sweet effect, then a peppery kick at the end. Very aromatic. The flavor is just bursting with complex hops, zesty earthy tones, sweet orange, peppery malt, clean fresh feel and overall vibe. A crispy bite wakes you up, full and lush mouthfeel follows from a totally unfiltered expereince. The feel and flavor finishes with a fun, earthy, zesty dry bite. Tropical juicy, zesty citrus, zippy golden wheat malt, melons, rustic earthiness sums up the taste pretty well. Levels of complexity are deep. It's an interesting ride for sure. Overall, this one stands somewhere near the top of the New England IPA's.
# 4           Classic TH NEIPA. Overflowing head and bouquet. Strong flavor but smoother than 8.2%. Maybe peach nose but overall a general citrus punch.
# 7           Pours a creamy opaque light straw yellow with a whispy frothy white head. Nose is of citrus skin and light pine. Taste is a thing of beauty! A nice citrus punch in the mouth. Both peeland zest as well as juice of oranges, grapefruit and lemon. Nice malt backbone although minimal presence, you know its there because the hoppyness of this beer is perfectly balanced. Meadium creamy body. Smooth to drink. Finishes with with a Nice pungent citrus bitterness that leaves you craving the next sip to start the process over again. By far my favorite Treehouse brew of the 4 or 5 I’ve had.
# 13          Pours a cloudy yellow color with a thin foamy head. Head retention is good. Lacing is very good. Has a big juicy citrus aroma. Nice juicy taste with a good amount of citrus and some piney resin at the end. Bitterness is spot on. A little on the heavy side, but excellent. Medium bodied with moderate carbonation.
# ...                                                                                                                                                                                                                                                                                                                                ...
# 9073095     Large chalky white head. Leaves lots of spotty lace. Foamy. Slightly hazy in an otherwise amber broth. Sweet, almost like maple syrup, smell. Lots of sugar and candy with a faint amount of Belgian yeast in the background. More dry than the smell indicates. Quite chewy. Very short aftertaste. Low level of hop bitterness. Still, it works in terms of balance. The swallow shows up a higher alcohol level than the ABV would indicate. In a word, I'd describe this beer as enigmatic.
# 9073096     pours a hazy, almost cloudy, autumn gold. Apparently unfiltered. Rich, off-white head settles to a tight, solid cap of foam. Aroma is straight up Belgian yeast, with the overripe fruit esters of banana and melon skin, and a hint of spice. Taste has a nice balance of sweet honey malts and tangy, bubblegum-y yeast. Floral, lemony hops come in strong, with a surprising cilantro-like soapy bitterness. Any sweetness begins to yield to dry, crackery malts and tart apple. All that's missing is a nice wedge of brie. Bitterness in the finish lingers a bit long for my taste and is my only real complaint. Nice rustic quality to it that is suggestive of a farmhouse ale or biere de garde. Terrific, weighty mouthfeel for a regular BPA without become heavy or cloying. A brisk carbonation helps in that regard, as does the dry finish. A bit to bitter for the style perhaps, but pair it with some rich cheese, a baguette and some fig preserves and you have a great picnic.
# 9073097     Pours a hazy golden/orange to copper with a big off white head packed with dense carbonation bubbles leaving a thin lacing in its wake. Nice aromas of yeast, pepper spice, banana, and coriander waft from the glass. As the beer warms, some sugar notes become apparent as well. Pleasant flavors as well, more up front sugar than the aroma, sweet fruit, banana, again coriander, but more floral hop bite in the finish. Medium to light in body, medium to high carbonation, somewhat dry finish, and a nice peppery bite to end. Good brew, perhaps not traditional of the style in all aspects, but quite tasty. The flavor characteristics are borderline aggressive, but I would not complain.
# 9073110     Appearance is dark dark brown with a half finger brown head that left quickly. Aroma is so luxurious. Milk chocolate, dark fruits, some toffee and bourbon. Also a sweet smell. Taste is dark fruit/toffee/caramel with slight chocolate and big big bourbon up front. Then the back end hits you with just enough roasted coffee bitterness. Mouthfeel is medium and doesn't have that long lingering flavor. That's the only thing about this beer I guess that's not perfect. The beer leaves a delicious sweet sticky film on my lips. So grateful to be able to try this. Take jones dog to the promised land!
# 9073114     Shared botte. A - Murky, brown, hardly any light could penetrate. S - Dark fruits, malty, hopped up, sugars. T - Smooth taste with hops and malt all in balance. Even for a young beer this BA version was practically ready to drink ASAP. M - Sublte carbonation as to not overtake the pleasant smooth trail of malt backbone. O - Quite delicious, wish I had one to age because it wouldve mellowed out a little and blended everything together. Perfect amount of time in the barrels, well done.
#
#          look  smell  taste  feel  overall  score
# 0        4.00  4.00   4.00   4.25  4.00     4.03
# 3        4.75  4.75   4.50   4.50  4.50     4.58
# 4        4.25  4.50   4.25   4.25  4.25     4.31
# 7        4.75  4.50   4.50   4.50  4.50     4.52
# 13       4.50  4.50   4.50   4.75  4.50     4.53
# ...       ...   ...    ...    ...   ...      ...
# 9073095  4.00  3.50   3.50   4.00  3.50     3.58
# 9073096  3.50  4.00   4.00   3.50  4.00     3.92
# 9073097  4.00  4.00   3.50   4.00  4.00     3.80
# 9073110  4.25  4.75   4.25   4.00  4.25     4.35
# 9073114  4.00  5.00   4.75   4.25  4.50     4.67
#
# [2823752 rows x 10 columns]

# %%
pd.set_option('display.max_colwidth', -1)

# %%
text_no_nan.beer_id.value_counts()
# Out:
# 11757     4168
# 2093      4159
# 7971      4029
# 1093      3963
# 412       3921
#           ...
# 76220        1
# 99447        1
# 128121       1
# 96694        1
# 97947        1
# Name: beer_id, Length: 136535, dtype: int64

# %%
# Just looking at the top reviewed beers - this one happens to be a personal favorite!
beers.loc[beers['id'] == 412]
# Out:
#         id          name  brewery_id state country                   style  \
# 25637  412  Old Rasputin         112    CA      US  Russian Imperial Stout
#
#       availability  abv                                              notes  \
# 25637   Year-round  9.0  Produced in the tradition of 18th Century Engl...
#
#       retired
# 25637       f

# %%
text_no_nan.loc[text_no_nan['beer_id'] == 412].score.mean()
# Out:
# 4.280094363682734

# %%
text_no_nan.loc[text_no_nan['beer_id'] == 1093].score.mean()
# Out:
# 4.262929598788797

# %%
# some beers have a 5.0 overall rating?
text_no_nan.groupby(['beer_id']).mean().max()
# Out:
# look       5.0
# smell      5.0
# taste      5.0
# feel       5.0
# overall    5.0
# score      5.0
# dtype: float64

# %%
(reviews[reviews.smell.isna() == True].index == reviews[reviews.overall.isna() == True].index).sum()
# Out:
# 3790018

# %%
reviews.loc[(reviews['text'] == '') & (reviews.smell.isna() == True)]
# Out:
#          beer_id          username        date text  look  smell  taste  feel  \
# 57        235178        Bryan12345  2016-06-12        NaN    NaN    NaN   NaN
# 70        104824        Reagan1984  2014-05-26        NaN    NaN    NaN   NaN
# 71        104824       Chibeerguy1  2014-05-26        NaN    NaN    NaN   NaN
# 72        104824         AaronBurr  2014-05-26        NaN    NaN    NaN   NaN
# 74        104824         dfhhead25  2014-05-24        NaN    NaN    NaN   NaN
# ...          ...               ...         ...  ...   ...    ...    ...   ...
# 9073123   104824            CTJman  2014-06-08        NaN    NaN    NaN   NaN
# 9073124   104824  IMSPEAKNOENGLISH  2014-06-06        NaN    NaN    NaN   NaN
# 9073125   104824          twizzard  2014-06-05        NaN    NaN    NaN   NaN
# 9073126   104824        bootdown21  2014-06-04        NaN    NaN    NaN   NaN
# 9073127   104824           Brensol  2014-06-01        NaN    NaN    NaN   NaN
#
#          overall  score
# 57           NaN   4.25
# 70           NaN   4.50
# 71           NaN   4.75
# 72           NaN   4.00
# 74           NaN   3.50
# ...          ...    ...
# 9073123      NaN   4.00
# 9073124      NaN   5.00
# 9073125      NaN   5.00
# 9073126      NaN   4.50
# 9073127      NaN   4.75
#
# [3625777 rows x 10 columns]

# %% [markdown]
# -----

# %%
breweries.loc[breweries.id == 1199]
# Out:
#          id                      name          city state country  \
# 34812  1199  Founders Brewing Company  Grand Rapids    MI      US
#
#                                                    notes  \
# 34812  Mahou San Miguel has a 30% ownership stake sin...
#
#                                   types
# 34812  Brewery, Bar, Eatery, Beer-to-go

# %%
# There are foreign breweries in the dataset - should I keep them?
breweries.loc[breweries.country == 'DE']
# Out:
#           id                                       name  \
# 83     33078                     Brauhaus Alter Elbehof
# 89     18049                      Landhaus - Krähennest
# 129     6200                                  Maxl Bräu
# 146    46383                          Munich Brew Mafia
# 147     6696  Adler Brauerei und Brennerei Gebhard Föhr
# ...      ...                                        ...
# 50208   5819                              Brauerei Goss
# 50255   6669                               Demmert Bräu
# 50283   7706                            Bolten Brauerei
# 50295   7602                        Brauerei Rechenberg
# 50313  12356                              Fichte Kränzi
#
#                          city state country                   notes  \
# 83                     Torgau   NaN      DE  No notes at this time.
# 89                Löf - Mosel   NaN      DE  No notes at this time.
# 129                   Neu-Ulm   NaN      DE  No notes at this time.
# 146                   München   NaN      DE  No notes at this time.
# 147                   Ehingen   NaN      DE  No notes at this time.
# ...                       ...   ...     ...                     ...
# 50208               Deuerling   NaN      DE  No notes at this time.
# 50255       Neuendorf Altmark   NaN      DE  No notes at this time.
# 50283          Korschenbroich   NaN      DE  No notes at this time.
# 50295  Rechenberg-Bienenmühle   NaN      DE  No notes at this time.
# 50313       Frankfurt am Main   NaN      DE  No notes at this time.
#
#                           types
# 83         Brewery, Bar, Eatery
# 89      Bar, Eatery, Beer-to-go
# 129                     Brewery
# 146                     Brewery
# 147                     Brewery
# ...                         ...
# 50208  Brewery, Bar, Beer-to-go
# 50255                   Brewery
# 50283                   Brewery
# 50295                   Brewery
# 50313               Bar, Eatery
#
# [1812 rows x 7 columns]

# %%
breweries.notes.unique()
# Out:
# array(['No notes at this time.',
#        'Duplicate of https://www.beeradvocate.com/beer/profile/36929',
#        'At Modist, we push past traditional brewing by embracing creativity and unconstrained experimentation. ',
#        ...,
#        'Pacific Rim is closed: http://beeradvocate.com/beer/profile/931 ',
#        'Big gourmet market, with a beer store and a beer bar in the basement.',
#        'Located on the Ground Floor of Oxford House in TaiKoo Place.'],
#       dtype=object)

# %%
# There are 58 breweries that don't have a listed city
breweries.city.isna().sum()
# Out:
# 58

# %%
breweries.loc[breweries.city.isna()]
# Out:
#           id                                               name city state  \
# 559     5616                      Hops! La Fabbrica della Birra  NaN   NaN
# 712     1552                      Big Buck Brewery & Steakhouse  NaN   NaN
# 1370     839                                    Tooheys Brewing  NaN   NaN
# 2097     915                      New Zealand Breweries Limited  NaN   NaN
# 2882   23973                             Sebago Brewing Company  NaN   NaN
# 2886    1802       Weeping Radish Brewery & Bavarian Restaurant  NaN   NaN
# 4843    3629                                          Frog Pubs  NaN   NaN
# 6830   34937                      3er Tiempo Tienda De Cervezas  NaN   NaN
# 6833    1553                               Shipyard Brewing Co.  NaN   NaN
# 7625    2357                                    Tinkoff Brewery  NaN   NaN
# 8529    2413                          Tied House Cafe & Brewery  NaN   NaN
# 10048   1274                                    Cerveza De Cuba  NaN   NaN
# 11935   5114                              Steelhead Brewing Co.  NaN   NaN
# 12878    918                          Hops Grillhouse & Brewery  NaN   NaN
# 14069  50381                                     Lübeck Cerveja  NaN   NaN
# 14190   6045                     Iron Hill Brewery & Restaurant  NaN   NaN
# 14546  48444                                   Brewlander & Co.  NaN   NaN
# 14846   6416                                    Triumph Brewing  NaN   NaN
# 16233    937                                   Stingray Brewery  NaN   NaN
# 16334   3079  Ram International / Humperdinks Restaurant and...  NaN   NaN
# 16895   4927                         Liberty Steakhouse Brewery  NaN   NaN
# 17625  49146                    K&L Italian Beers Manufacturing  NaN   NaN
# 17854   1931                    Barley's Smokehouse and Brewpub  NaN   NaN
# 17861   1819                        Granite City Food & Brewery  NaN   NaN
# 18664   2410               Hereford & Hops Restaurant & Brewpub  NaN   NaN
# 18866   2730                      Jacob Leinenkugel Brewing Co.  NaN   NaN
# 19207  46046                             Verhovinska Pivovarnya  NaN   NaN
# 19356   2776                             Empire Brewing Company  NaN   NaN
# 19843   1751                        Two Rows Breweries & Grills  NaN   NaN
# 20448  49728                                        Fat Sparrow  NaN   NaN
# 20777  47050                   La Arboleda Cervecería Artesanal  NaN   NaN
# 23234     70                          Full Sail Brewing Company  NaN   NaN
# 27017    626                                      Mac's Brewery  NaN   NaN
# 27303  28908                           Utah Brewers Cooperative  NaN    UT
# 28838   4343                              E & O Trading Company  NaN   NaN
# 29134   1793                       Capitol City Brewing Company  NaN   NaN
# 29260   1927              Il Vicino Wood Oven Pizza and Brewery  NaN   NaN
# 30064  52307                          Cliff Top Brewing Company  NaN   NaN
# 30200   1567                Brew Moon Restaurant & Microbrewery  NaN   NaN
# 30314  11016             Privatbrauerei Josef / Trumer Brauerei  NaN   NaN
# 31685   1672                             Prague Breweries Group  NaN   NaN
# 31760   2434                         Blue Corn Cafe and Brewery  NaN   NaN
# 33412   1554                         Buckhead Brewery and Grill  NaN   NaN
# 34226   2900                                   Paulista Brewery  NaN   NaN
# 37574    200                          Mendocino Brewing Company  NaN   NaN
# 38147   1550                   Rock Bottom Restaurant & Brewery  NaN   NaN
# 39211  47176                                        Bokkereyder  NaN   NaN
# 41272    445                                     Bedele Brewery  NaN   NaN
# 41280   8451                                Snake River Brewing  NaN   NaN
# 42344   2104                                         McMenamins  NaN   NaN
# 43191   1551                  Gordon Biersch Brewery Restaurant  NaN   NaN
# 45015   2710                  BJ's Chicago Pizza & Brewery Inc.  NaN   NaN
# 45345  18989                           Barley's Brewing Company  NaN   NaN
# 45376   2512                             Sonora Brewing Company  NaN   NaN
# 45839   3681                        Thirsty Dog Brewing Company  NaN   NaN
# 48267  41692                             Bennett's Bar & Lounge  NaN   NaN
# 48810    887                                        Utenos Alus  NaN   NaN
# 48850   1961                            Sea Dog Brewing Company  NaN   NaN
#
#       country                                              notes  \
# 559        IT                             No notes at this time.
# 712        US                             No notes at this time.
# 1370       AU                             No notes at this time.
# 2097       NZ                             No notes at this time.
# 2882       US                             No notes at this time.
# 2886       US                             No notes at this time.
# 4843       FR                             No notes at this time.
# 6830       ES                             No notes at this time.
# 6833       US                             No notes at this time.
# 7625       RU                             No notes at this time.
# 8529       US                             No notes at this time.
# 10048      CU                             No notes at this time.
# 11935      US                             No notes at this time.
# 12878      US                             No notes at this time.
# 14069      BR                             No notes at this time.
# 14190      US                             No notes at this time.
# 14546      SG                             No notes at this time.
# 14846      US                             No notes at this time.
# 16233      KY                                 Closed on Sundays.
# 16334      US                             No notes at this time.
# 16895      US                             No notes at this time.
# 17625      IT                             No notes at this time.
# 17854      US                             No notes at this time.
# 17861      US                             No notes at this time.
# 18664      US                             No notes at this time.
# 18866      US                             No notes at this time.
# 19207      UA                             No notes at this time.
# 19356      US                             No notes at this time.
# 19843      US                             No notes at this time.
# 20448      ES                        Brewed at Cerveza Dougall’s
# 20777      CR                             No notes at this time.
# 23234      US                             No notes at this time.
# 27017      NZ                             No notes at this time.
# 27303      US                             No notes at this time.
# 28838      US                             No notes at this time.
# 29134      US                             No notes at this time.
# 29260      US                             No notes at this time.
# 30064      BE                             No notes at this time.
# 30200      US  The old Brew Moon chain of brewpubs. Now close...
# 30314     NaN                             No notes at this time.
# 31685      CZ                             No notes at this time.
# 31760      US                             No notes at this time.
# 33412      US                             No notes at this time.
# 34226      BR                             No notes at this time.
# 37574      US                             No notes at this time.
# 38147      US                             No notes at this time.
# 39211      BE                             No notes at this time.
# 41272      ET                             No notes at this time.
# 41280      US                             No notes at this time.
# 42344      US                             No notes at this time.
# 43191      US                             No notes at this time.
# 45015      US                             No notes at this time.
# 45345     NaN                             No notes at this time.
# 45376      US                             No notes at this time.
# 45839      US                             No notes at this time.
# 48267      IE                             No notes at this time.
# 48810      LT                             No notes at this time.
# 48850      US          Brewed and bottled by Pugsley Brewing LLC
#
#                       types
# 559                 Brewery
# 712                 Brewery
# 1370                Brewery
# 2097                Brewery
# 2882                Brewery
# 2886                Brewery
# 4843                Brewery
# 6830                  Store
# 6833                Brewery
# 7625                Brewery
# 8529                Brewery
# 10048               Brewery
# 11935               Brewery
# 12878               Brewery
# 14069               Brewery
# 14190               Brewery
# 14546               Brewery
# 14846               Brewery
# 16233               Brewery
# 16334               Brewery
# 16895               Brewery
# 17625               Brewery
# 17854               Brewery
# 17861               Brewery
# 18664               Brewery
# 18866               Brewery
# 19207               Brewery
# 19356               Brewery
# 19843               Brewery
# 20448               Brewery
# 20777               Brewery
# 23234               Brewery
# 27017               Brewery
# 27303               Brewery
# 28838               Brewery
# 29134               Brewery
# 29260               Brewery
# 30064               Brewery
# 30200  Brewery, Bar, Eatery
# 30314               Brewery
# 31685               Brewery
# 31760               Brewery
# 33412               Brewery
# 34226               Brewery
# 37574               Brewery
# 38147               Brewery
# 39211               Brewery
# 41272               Brewery
# 41280               Brewery
# 42344               Brewery
# 43191               Brewery
# 45015               Brewery
# 45345               Brewery
# 45376               Brewery
# 45839               Brewery
# 48267                   Bar
# 48810               Brewery
# 48850               Brewery

# %% [markdown]
# # BEERS

# %%
# A lot of IPAs! To be expected
beers['style'].value_counts()[:50]
# Out:
# American IPA                                   44719
# American Pale Ale (APA)                        22159
# American Imperial IPA                          18338
# Belgian Saison                                 18167
# American Wild Ale                              12972
# American Imperial Stout                        11180
# American Porter                                10168
# American Amber / Red Ale                        9748
# American Stout                                  9103
# Fruit and Field Beer                            7729
# American Blonde Ale                             7089
# American Brown Ale                              7008
# German Hefeweizen                               6020
# Belgian Witbier                                 5613
# American Pale Wheat Ale                         5266
# Berliner Weisse                                 5036
# German Pilsner                                  4748
# Belgian Pale Ale                                4523
# Russian Imperial Stout                          4426
# English Sweet / Milk Stout                      4192
# American Black Ale                              4015
# English Bitter                                  3801
# Belgian Tripel                                  3783
# American Lager                                  3741
# European Pale Lager                             3715
# English Pale Ale                                3682
# German Märzen / Oktoberfest                     3583
# Leipzig Gose                                    3336
# American Barleywine                             3264
# German Kölsch                                   3191
# English Oatmeal Stout                           3045
# Herb and Spice Beer                             2928
# Belgian Strong Pale Ale                         2898
# Bohemian Pilsener                               2895
# English Extra Special / Strong Bitter (ESB)     2893
# Scotch Ale / Wee Heavy                          2700
# Belgian Strong Dark Ale                         2683
# Rye Beer                                        2638
# American Cream Ale                              2540
# American Strong Ale                             2509
# English India Pale Ale (IPA)                    2427
# English Brown Ale                               2398
# Belgian Dubbel                                  2376
# Belgian IPA                                     2268
# English Porter                                  2263
# Pumpkin Beer                                    2180
# New England IPA                                 2154
# Irish Red Ale                                   2080
# German Doppelbock                               1976
# Irish Dry Stout                                 1956
# Name: style, dtype: int64

# %%
# Out:
# Index(['American IPA', 'American Pale Ale (APA)', 'American Imperial IPA',
#        'Belgian Saison', 'American Wild Ale', 'American Imperial Stout',
#        'American Porter', 'American Amber / Red Ale', 'American Stout',
#        'Fruit and Field Beer',
#        ...
#        'American Brut IPA', 'Belgian Lambic', 'German Eisbock',
#        'Robust Porter', 'Japanese Rice Lager', 'Japanese Happoshu',
#        'Finnish Sahti', 'Bière de Champagne / Bière Brut', 'Belgian Faro',
#        'Wild/Sour Beers'],
#       dtype='object', length=112)

# %%
labels = beers['style'].value_counts()[:10].index

# %%
ax = sns.barplot(x=beers['style'].value_counts()[:10].index, y=beers['style'].value_counts()[:10], hue=beers['style'].value_counts()[:10].index, hue_order = labels)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right');
# ax.legend(loc='best', bbox_to_anchor=(0.5, 0., 0.5, 0.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d2c8febf775> in <module>
# ----> 1 ax = sns.barplot(x=beers['style'].value_counts()[:10].index, y=beers['style'].value_counts()[:10], hue=beers['style'].value_counts()[:10].index, hue_order = labels)
#       2 ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right');
#       3 # ax.legend(loc='best', bbox_to_anchor=(0.5, 0., 0.5, 0.5))
#
# NameError: name 'sns' is not defined

# %%
sns.distplot(beers['style'].value_counts(),kde=False)

# %%
beers['availability'].value_counts()
# Out:
#  Rotating                  98776
#  Limited (brewed once)     72047
#  Year-round                56800
# Rotating                   48002
# Limited (brewed once)      34798
# Year-round                 19744
#  Winter                     6427
#  Fall                       5908
#  Summer                     5136
#  Spring                     3349
# Fall                        2310
# Winter                      2293
# Summer                      1973
# Spring                      1286
#  Limited (brewed once)         9
#  Rotating                      6
#  Year-round                    4
#  Fall                          3
#  Winter                        1
#  Summer                        1
# Name: availability, dtype: int64

# %%
(beers['availability'] == ' Rotating').sum()
# Out:
# 98776

# %%
(beers['availability'] == 'Rotating').sum()
# Out:
# 48002

# %%
beers['availability'] = beers['availability'].replace(' Rotating', 'Rotating')
beers['availability'] = beers['availability'].replace(' Rotating ', 'Rotating')
beers['availability'] = beers['availability'].replace(' Limited (brewed once)', 'Limited (brewed once)')
beers['availability'] = beers['availability'].replace(' Limited (brewed once) ', 'Limited (brewed once)')
beers['availability'] = beers['availability'].replace(' Year-round', 'Year-round')
beers['availability'] = beers['availability'].replace(' Year-round ', 'Year-round')
beers['availability'] = beers['availability'].replace(' Winter', 'Winter')
beers['availability'] = beers['availability'].replace(' Winter ', 'Winter')
beers['availability'] = beers['availability'].replace(' Fall', 'Fall')
beers['availability'] = beers['availability'].replace(' Fall ', 'Fall')
beers['availability'] = beers['availability'].replace(' Summer', 'Summer')
beers['availability'] = beers['availability'].replace(' Summer ', 'Summer')
beers['availability'] = beers['availability'].replace(' Spring', 'Spring')
beers['availability'] = beers['availability'].replace(' Spring ', 'Spring')

# %%
# Not sure if having the availability play into the recommendations or not. Since most are
# 'rotating', which is incredibly vague.
beers['availability'].value_counts()
# Out:
# Rotating                 146784
# Limited (brewed once)    106854
# Year-round                76548
# Winter                     8721
# Fall                       8221
# Summer                     7110
# Spring                     4635
# Name: availability, dtype: int64

# %%
beers.loc[(beers['country'] == 'US') | (beers['country'] == 'CA')]
# Out:
#             id                      name  brewery_id state country  \
# 0       202522            Olde Cogitator        2199    CA      US
# 2       214879            Scottish Right       44306    IN      US
# 3       320009   MegaMeow Imperial Stout        4378    WA      US
# 4       246438           Peaches-N-Cream       44617    PA      US
# 6       108605               Icon Sender       22598    CA      US
# ...        ...                       ...         ...   ...     ...
# 358867  146613         American Pale Ale       36926    WI      US
# 358868  267703  Collective Project: Gose       32763    ON      CA
# 358870  187618                     RIPTA       34665    RI      US
# 358871  283124               Rumble Fish       29238    MI      US
# 358872  267484             Joie De Vivre       25032    CA      US
#
#                           style           availability  abv  \
# 0         English Oatmeal Stout               Rotating  7.3
# 2                  Scottish Ale             Year-round  4.0
# 3       American Imperial Stout                 Winter  8.7
# 4            American Cream Ale               Rotating  5.1
# 6                American Lager             Year-round  5.6
# ...                         ...                    ...  ...
# 358867  American Pale Ale (APA)               Rotating  NaN
# 358868             Leipzig Gose  Limited (brewed once)  5.0
# 358870           Belgian Tripel               Rotating  9.5
# 358871    American Imperial IPA               Rotating  8.3
# 358872           Belgian Saison  Limited (brewed once)  6.6
#
#                                                     notes retired  \
# 0                                  No notes at this time.       f
# 2                                  No notes at this time.       t
# 3                                    Every time this year       f
# 4                                  No notes at this time.       f
# 6                                  No notes at this time.       f
# ...                                                   ...     ...
# 358867                             No notes at this time.       t
# 358868  Our Gose is an unfiltered wheat beer made with...       t
# 358870                             No notes at this time.       f
# 358871                             No notes at this time.       f
# 358872                             No notes at this time.       t
#
#                   availbility
# 0                    Rotating
# 2                  Year-round
# 3                      Winter
# 4                    Rotating
# 6                  Year-round
# ...                       ...
# 358867               Rotating
# 358868  Limited (brewed once)
# 358870               Rotating
# 358871               Rotating
# 358872  Limited (brewed once)
#
# [286983 rows x 11 columns]

# %% [markdown]
# ### 118k are retired beers

# %%
beers['retired'].value_counts()
# Out:
# f    240480
# t    118393
# Name: retired, dtype: int64

# %%
# subset to only non-retired beers
current_beer = beers[beers['retired'] == 'f']

# %%
current_beer.sample(20)
# Out:
#             id                                              name  brewery_id  \
# 154246  302218                                              Oakd       44537
# 34442   206157                                  Santa's Schwarts       25844
# 265271  123322                                 Tashka Double IPA       33392
# 347826  221096                                       Hot Moz IPA       14430
# 167561  288400                                      Okay Alright       41462
# 323227  311592                                     Motherboy IPA       44793
# 129824  350589              Double Dry Hopped Coastal Evacuation       25890
# 5787    228186                                    Happy Accident       42081
# 115409  285757  Sleepy Bear W/ Cacao Nibs, Vanilla & Raspberries       36002
# 255500  208140                                     Appaloosa IPA       43252
# 91328   223931                                           Theorem       30026
# 139400  317196                             BYO Jeff Williams IPA       46535
# 94370   355969                           Strawberry Steve Murkel       52531
# 87750   114877                                 Tucker's Pale Ale       18159
# 56693   227296                 Stalin's Darkside Rum Barrel Aged       32832
# 322087  298085  Wild Turkey Bourbon Barrel-Aged Kilty MacSporran       38100
# 320956  240767                                              Duck       14662
# 252953  334354                                       Choco-citra       40874
# 91579   349271                             Simcoe Smash Pale Ale       38287
# 304776  149771                                   German Pale Ale       15673
#
#        state country                        style            availability  \
# 154246    OH      US  German Märzen / Oktoberfest                    Fall
# 34442     NY      US              American Porter                Rotating
# 265271    AL      US        American Imperial IPA              Year-round
# 347826    PA      US                 American IPA                Rotating
# 167561    WI      US      American Pale Wheat Ale                  Summer
# 323227    KY      US                 American IPA                Rotating
# 129824    NJ      US        American Imperial IPA   Limited (brewed once)
# 5787      PA      US            American Wild Ale                Rotating
# 115409    IL      US       Russian Imperial Stout                Rotating
# 255500    OR      US                 American IPA                Rotating
# 91328     IN      US   English Sweet / Milk Stout                Rotating
# 139400    PA      US                 American IPA   Limited (brewed once)
# 94370     CA      US      American Pale Ale (APA)                Rotating
# 87750     FL      US      American Pale Ale (APA)              Year-round
# 56693     IN      US       Russian Imperial Stout                Rotating
# 322087    WA      US       Scotch Ale / Wee Heavy                Rotating
# 320956   NaN      IT      Belgian Strong Pale Ale              Year-round
# 252953    KY      US           American Brown Ale                Rotating
# 91579     WA      US      American Pale Ale (APA)                Rotating
# 304776   GB6      GB                German Kölsch              Year-round
#
#          abv                                              notes retired
# 154246   5.7                             No notes at this time.       f
# 34442    5.4                             No notes at this time.       f
# 265271   8.6                             No notes at this time.       f
# 347826   6.8                             No notes at this time.       f
# 167561   5.0                             No notes at this time.       f
# 323227   NaN                             No notes at this time.       f
# 129824   8.0  Double dry-hopped with Galaxy and Mosaic, DDH ...       f
# 5787     5.8  Apricot and stone fruit aromas with complex es...       f
# 115409   9.6                             No notes at this time.       f
# 255500   6.2                             No notes at this time.       f
# 91328    5.0                             No notes at this time.       f
# 139400   5.2                             No notes at this time.       f
# 94370    5.5                             No notes at this time.       f
# 87750    5.5                             No notes at this time.       f
# 56693   10.0                             No notes at this time.       f
# 322087   5.8  Our beloved Kilty MacSporran Scottish Ale aged...       f
# 320956   8.0                             No notes at this time.       f
# 252953   6.7                             No notes at this time.       f
# 91579    6.3                             No notes at this time.       f
# 304776   5.2                             No notes at this time.       f

# %% [markdown]
# ### Join non-retired beers df to our current list of reviews (text_no_nan)

# %%
text_no_nan.head()
# Out:
#     beer_id         username        date  \
# 0    271781     bluejacket74  2017-03-17
# 3    125646  GratefulBeerGuy  2017-12-20
# 4    125646         LukeGude  2017-12-20
# 7    125646             MFMB  2017-12-16
# 13   125646      jngrizzaffi  2017-12-10
#
#                                                  text  look  smell  taste  \
# 0      750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00   4.00
# 3      0% 16 oz can. Funny story: As I finally wal...  4.75   4.75   4.50
# 4      Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50   4.25
# 7      Pours a creamy opaque light straw yellow wi...  4.75   4.50   4.50
# 13     Pours a cloudy yellow color with a thin foa...  4.50   4.50   4.50
#
#     feel  overall  score
# 0   4.25     4.00   4.03
# 3   4.50     4.50   4.58
# 4   4.25     4.25   4.31
# 7   4.50     4.50   4.52
# 13  4.75     4.50   4.53

# %%
text_no_nan = text_no_nan.rename(columns={'beer_id':'id'})
reviews_beer = pd.merge(text_no_nan, current_beer,
                        left_on = 'id',
                        right_on = 'id')

# %% [markdown]
# There are 22,514 beers with 10+ reviews

# %%
(reviews_beer.id.value_counts() > 1).sum()
# Out:
# 69749

# %%
# group by beer_id ('id') and take the mean of all reviews for that beer
ratings = pd.DataFrame(reviews_beer.groupby('id')['score'].mean())
ratings.head()
# Out:
#        score
# id
# 5   3.389863
# 6   3.643678
# 7   3.235484
# 9   3.087823
# 10  3.797290

# %%
# add a column tallying the # of reviews for each beer, rename score, and subset out 
# reviews with 9 or less total reviews
ratings['no_of_ratings'] = reviews_beer.groupby('id')['score'].count()
ratings = ratings.rename(columns={'score':'avg_score'})
ratings = ratings.loc[ratings['no_of_ratings'] > 9]

# %%
ratings.sample(5)
# Out:
#        avg_score  no_of_ratings
# id
# 9508    3.265405             37
# 5537    3.691977             86
# 91126   3.941176             17
# 66920   3.846000             20
# 71800   3.109167             12

# %%
# rejoin the engineered features onto the original review_beer df
df = reviews_beer.merge(ratings, how='inner', on='id')
df.shape
# Out:
# (2265731, 21)

# %%
# now going to look at average score and number of reviews for each USER, then subset
# to those with 5+ reviews
reviewers = pd.DataFrame(df.groupby('username')['id'].count())
reviewers['avg_usr_score'] = df.groupby('username')['score'].mean()
reviewers = reviewers.loc[reviewers['id'] > 4]

# %%
reviewers.head()
# Out:
#                   id  avg_usr_score
# username
# --Dom--           45       4.293778
# --weezl--          5       4.070000
# -DF-               6       3.896667
# -Hoptimus_Prime-   5       3.670000
# -MK-               8       4.296250

# %%
# renaming ID to tot_usr_rvw
reviewers = reviewers.rename(columns={'id':'tot_usr_rvw'})

# %%
# visualize the distribution of users and their # of reviews and average score given
sns.jointplot(x='avg_usr_score', y='tot_usr_rvw', data = reviewers)

# %%
# there are 26k unique users
reviewers.shape
# Out:
# (26376, 2)

# %%
reviewer_std = reviewers['avg_usr_score'].std()
reviewer_mean = reviewers['avg_usr_score'].mean()
print(reviewer_mean + (reviewer_std*2))
print(reviewer_mean - (reviewer_std*2))
# Out:
# 4.668145351321007
# 3.173760941274998

# %%
# removing users outside of 2STD of the mean average score
# the thought is that some reviewers might be too generous, or too harsh in general
# Cutting out 2std above the mean makes sense as someone with an average score of 4.7+
# is either only drinking the best, or their view is skewed.
# To maintain consistency I also removed 2STD below, but it could be argued that the 
# lowerbound of the cutoff should be lower

reviewers_sub = reviewers.loc[(reviewers['avg_usr_score'] >= 3.182) &\
                              (reviewers['avg_usr_score'] <= 4.665)]

# %%
# Lose 1400 users
reviewers_sub.shape
# Out:
# (24901, 2)

# %%
sns.jointplot(x='avg_usr_score', y='tot_usr_rvw', data = reviewers_sub)

# %%
df_with_mins = df.merge(reviewers_sub, how = 'inner', on = 'username')

# %%
df_with_mins.shape
# Out:
# (2144276, 23)

# %% [markdown]
# My work continues in the 1.0 Recommender Jupyter Notebook
